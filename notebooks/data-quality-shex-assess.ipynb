# %% [markdown]
# ## Assessing the data quality based on the RDF data generated
#
# This notebook shows how to use the ShEx against the RDF data generated.

# %% [markdown]
# ### First we load the python packages libraries

# %%
from pyshex.evaluate import evaluate
from rdflib import Graph, Namespace, XSD

# %% [markdown]
# ### Then we describe the ShEx schema

# %%
# ShEx schema
shex = """
PREFIX schema: <https://schema.org/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX ex: <https://example.org/>
PREFIX : <http://weso.es/shapes/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX void: <http://rdfs.org/ns/void#>
PREFIX creativeCommons: <http://creativecommons.org/ns#>
PREFIX dc: <http://purl.org/dc/terms/>
PREFIX bibo: <http://purl.org/ontology/bibo/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX brick: <https://brickschema.org/schema/Brick#>
PREFIX csvw: <http://www.w3.org/ns/csvw#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX dcat: <http://www.w3.org/ns/dcat#>
PREFIX dcmitype: <http://purl.org/dc/dcmitype/>
PREFIX dcam: <http://purl.org/dc/dcam/>
PREFIX doap: <http://usefulinc.com/ns/doap#>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
PREFIX org: <http://www.w3.org/ns/org#>
PREFIX prof: <http://www.w3.org/ns/dx/prof/>
PREFIX prov: <http://www.w3.org/ns/prov#>
PREFIX qb: <http://purl.org/linked-data/cube#>
PREFIX sh: <http://www.w3.org/ns/shacl#>
PREFIX sosa: <http://www.w3.org/ns/sosa/>
PREFIX ssn: <http://www.w3.org/ns/ssn/>
PREFIX time: <http://www.w3.org/2006/time#>
PREFIX vann: <http://purl.org/vocab/vann/>
PREFIX wgs: <https://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX xml: <http://www.w3.org/XML/1998/namespace/>

start = @weso-s:CreativeWork

weso-s:CreativeWork
{
   rdf:type  [schema:CreativeWork]  ;                          # 100.0 %
   schema:encodingFormat  xsd:string  ;                        # 100.0 %
   schema:license  IRI  ;                                      # 100.0 %
   schema:isPartOf  IRI  ;                                     # 100.0 %
   schema:sourceOrganization  IRI  ;                           # 100.0 %
   schema:additionalType  xsd:string  ;                        # 100.0 %
   schema:name  xsd:string  ;                                  # 100.0 %
   schema:abstract  xsd:string  ;                              # 100.0 %
   schema:datePublished  xsd:string  ;                         # 100.0 %
   schema:identifier  xsd:string  ?
            # 98.50746268656717 % obj: xsd:string. Cardinality: {1}
}


weso-s:Person
{
   rdf:type  [schema:Person]  ;                                # 100.0 %
   rdf:type  [foaf:Person]  ;                                  # 100.0 %
   foaf:name  xsd:string  +;                                   # 100.0 %
   skos:prefLabel  xsd:string  +;                              # 100.0 %
   schema:name  xsd:string  +                                  # 100.0 %
}

"""

# %% [markdown]
# ### We load our dataset and assess the resources

# %%
# We define the name of the input folder and file
folder_name = 'chile'
file_name = 'chile'

input_nt_file = "../datos/output/"+folder_name+"/dataset_"+file_name+".ttl"

# %%
g = Graph()
g.parse(input_nt_file, format="turtle")


rslt, reason = evaluate(g, shex, focus="https://archivospatrimoniales.uc.cl/handle/123456789/31561")
if rslt:
    print("CONFORMS")
else:
    print(f"{reason if reason else 'DOES NOT CONFORM'}")
# Out:
#   Testing <https://archivospatrimoniales.uc.cl/handle/123456789/31561> against shape CreativeWork
#     Triples:
#       <https://archivospatrimoniales.uc.cl/handle/123456789/31561> rdf:type schema:CreativeWork .
#       <https://archivospatrimoniales.uc.cl/handle/123456789/31561> rdf:type schema:VideoObject .
#    2 triples exceeds max {1,1}

# %% [markdown]
# #### References
#
# - Daniel Fernández-Álvarez, José Emilio Labra Gayo, Daniel Gayo-Avello:
# Automatic extraction of shapes using sheXer. Knowl. Based Syst. 238: 107975 (2022)
